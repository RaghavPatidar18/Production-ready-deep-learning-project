# %% [markdown]
# Download data

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1-ALOe5trwgFDiwaIp3VxwvWg2Cc4KxuL/view?usp=drive_link"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
print(file_id)
# Out:
# 1-ALOe5trwgFDiwaIp3VxwvWg2Cc4KxuL

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, output, quiet=False)

import zipfile
with zipfile.ZipFile('data.zip', 'r') as zip_ref:
    zip_ref.extractall()
